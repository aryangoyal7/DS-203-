# %% [markdown]
# <a href="https://colab.research.google.com/github/aryangoyal7/DS-203-/blob/main/Project_week_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive

drive.mount(‘/content/MyDrive’)
# Out:
#   File "<ipython-input-2-94b4731775a6>", line 3
#     drive.mount(‘/content/MyDrive’)
#                 ^
# SyntaxError: invalid character in identifier

# %%
import pandas as pd
 
df = pd.read_csv('/content/drive/MyDrive/projectweek/ng.csv')
print(df)
# Out:
#       UTC UT_33_38  Nelamangala Karnataka              IST   Temperature_F  \
# 0                        01-12-2019 00:00  01-12-2019 05:30          77.71
# 1                        01-12-2019 01:00  01-12-2019 06:30          77.97
# 2                        01-12-2019 02:00  01-12-2019 07:30          78.27
# 3                        01-12-2019 03:00  01-12-2019 08:30          79.57
# 4                        01-12-2019 04:00  01-12-2019 09:30          80.70
# ...                                   ...               ...            ...
# 25254                                 NaN               NaN            NaN
# 25255                                 NaN               NaN            NaN
# 25256                                 NaN               NaN            NaN
# 25257                                 NaN               NaN            NaN
# 25258                                 NaN               NaN            NaN
#
#        Humidity_%  PM2.5_ATM_ug/m3  PM10_ATM_ug/m3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25259 entries, 0 to 25258
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   UTC UT_33_38  Nelamangala Karnataka  20100 non-null  object
#  1   IST                                  20100 non-null  object
#  2   Temperature_F                        20086 non-null  float64
#  3   Humidity_%                           20086 non-null  float64
#  4   PM2.5_ATM_ug/m3                      20086 non-null  float64
#  5   PM10_ATM_ug/m3                       20085 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 1.2+ MB

# %%
df.head()
# Out:
#   UTC UT_33_38  Nelamangala Karnataka              IST   Temperature_F  \
# 0                    01-12-2019 00:00  01-12-2019 05:30          77.71
# 1                    01-12-2019 01:00  01-12-2019 06:30          77.97
# 2                    01-12-2019 02:00  01-12-2019 07:30          78.27
# 3                    01-12-2019 03:00  01-12-2019 08:30          79.57
# 4                    01-12-2019 04:00  01-12-2019 09:30          80.70
#
#    Humidity_%  PM2.5_ATM_ug/m3  PM10_ATM_ug/m3
# 0       69.71            29.61           34.20
# 1       69.77            39.11           45.01
# 2       67.80            47.74           58.80
# 3       66.03            48.57           58.42
# 4       64.67            42.51           51.32

# %%
from matplotlib import pyplot as plt

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff310129ad0>,
# ...
#       dtype=object)

# %%
df.hist(column='PM2.5_ATM_ug/m3', bins = 10 , range=[0, 50],edgecolor='black', linewidth=1.2)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff3101cdc10>]],
#       dtype=object)

# %%
df.hist(column='PM10_ATM_ug/m3', bins = 10 , range=[0, 50],edgecolor='black', linewidth=1.2)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff310675bd0>]],
#       dtype=object)

# %%
df.plot(x='PM10_ATM_ug/m3', y='PM2.5_ATM_ug/m3', style='o')
df.plot(x='PM2.5_ATM_ug/m3', y='Humidity_%', style='o')
df.plot(x='PM10_ATM_ug/m3', y='Humidity_%', style='o')
df.plot(x='PM2.5_ATM_ug/m3', y='Temperature_F', style=['o','rx'])

# %%
df.loc[732,'UTC UT_33_38  Nelamangala Karnataka']
# Out:
# '31-12-2019 12:00'

# %%
df['UTC UT_33_38  Nelamangala Karnataka'] = pd.to_datetime(df['UTC UT_33_38  Nelamangala Karnataka'])

# %%
df.loc[34,'UTC UT_33_38  Nelamangala Karnataka'].day_name()
# Out:
# 'Tuesday'

# %%
p = df['PM2.5_ATM_ug/m3']
y =df['Humidity_%']
q = df['PM10_ATM_ug/m3']
e = df['Temperature_F']

plt.xlabel("hours")
p.plot()

# %%
plt.plot( q)


plt.ylabel("PM10_ATM_ug/m3")
plt.xlabel("hours")

plt.show()

# %%
plt.plot( e)


plt.ylabel("Temperature")
plt.xlabel("hours")

plt.show()

# %%
plt.plot( p)


plt.ylabel("PM2.5_ATM_ug/m3")
plt.xlabel("hours")

plt.show()

# %%
plt.plot( y)


plt.ylabel("Humidity_%")
plt.xlabel("hours")
plt.xlim([-1000, 21000])
#plt.xticks([0, 1000, 2000, 3000,4000,5000,6000,7000,8000,9000,10000,11000,12000,13000,14000,15000,16000,17000,18000,19000])

plt.show()
